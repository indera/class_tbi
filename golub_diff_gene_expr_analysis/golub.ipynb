# %%
"""
Goal: implement differential expression analysis
for two Leukemia conditions usig the Z-test.

Notes:

- The data for this analysis was downloaded from
    http://portals.broadinstitute.org/cgi-bin/cancer/publications/pub_paper.cgi?mode=view&paper_id=43
- This code is an adaptation for pandas of the code provided at
    http://dept.stat.lsa.umich.edu/~kshedden/Python-Workshop/gene_expression_comparison.html
    which uses data in "SOFT" format -- https://www.ncbi.nlm.nih.gov/sites/GDSbrowser?acc=GDS1615


@author: Andrei Sura
@see https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3134237/ - Gene Set Enrichment Analysis Made Simple
@see http://www.gettinggeneticsdone.com/2012/03/pathway-analysis-for-high-throughput.html

#########################################################
# Expression profiling in early onset colorectal cancer
@see http://clincancerres.aacrjournals.org/content/13/4/1107.full-text.pdf
@see https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE4107

@see http://isites.harvard.edu/fs/docs/icb.topic1517419.files/golub_analysis.R
@see http://svitsrv25.epfl.ch/R-doc/library/multtest/doc/golub.R

@see https://www.biostars.org/p/16137/
@see http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0012336
@see http://bioinformatics.mdanderson.org/MicroarrayCourse/Lectures09/ma10b.pdf
@see http://sebastianraschka.com/Articles/2014_pca_step_by_step.html

@see https://www.biostars.org/p/42219/ - pathway analysis
"""

import pandas as pd
import numpy as np
from scipy.stats.distributions import norm
# np.seterr(invalid='ignore')

IN_FILE = '/Users/asura/git/gene_expression_two_group_comparison/_golub_assignment/data_set_ALL_AML_train.csv'
OUT_FILE = '/Users/asura/git/gene_expression_two_group_comparison/_golub_assignment/out.csv'

# RANGE_ALL = ["call.{}".format(x) for x in range(0, 27)]
# RANGE_AML = ["call.{}".format(x) for x in range(27, 38)]
RANGE_ALL = ["data_{}".format(x) for x in range(1, 28)]
RANGE_AML = ["data_{}".format(x) for x in range(28, 39)]


"""
38 samples divided in two groups:
- ALL: 27 (1 to 27)  
- AML: 11 (28 to 38)

An accession number in bioinformatics is a unique identifier given to a DNA
or protein sequence record to allow for tracking of different versions of
that sequence record and the associated sequence over time in a single data
repository. Because of its relative stability, accession numbers can be 
utilized as foreign keys for referring to a sequence object, but not necessarily
to a unique sequence. All sequence information repositories implement the
concept of "accession number" but might do so with subtle variations.

"""
df = pd.read_csv(IN_FILE, sep='\t', index_col=False, skipinitialspace=False, nrows=None)
df.head()
# Out:
#                       Gene_Description Gene_Accession_Number  data_1 call_1  \
# 0  AFFX-BioB-5_at (endogenous control)        AFFX-BioB-5_at    -214      A
# 1  AFFX-BioB-M_at (endogenous control)        AFFX-BioB-M_at    -153      A
# 2  AFFX-BioB-3_at (endogenous control)        AFFX-BioB-3_at     -58      A
# 3  AFFX-BioC-5_at (endogenous control)        AFFX-BioC-5_at      88      A
# 4  AFFX-BioC-3_at (endogenous control)        AFFX-BioC-3_at    -295      A
#
#    data_2 call_2  data_3 call_3  data_4 call_4   ...    data_29 call_29  \
# 0    -139      A     -76      A    -135      A   ...         15       A
# 1     -73      A     -49      A    -114      A   ...       -114       A
# 2      -1      A    -307      A     265      A   ...          2       A
# 3     283      A     309      A      12      A   ...        193       A
# 4    -264      A    -376      A    -419      A   ...        -51       A
#
#    data_30 call_30  data_31 call_31  data_32 call_32  data_33 call_33
# 0     -318       A      -32       A     -124       A     -135       A
# 1     -192       A      -49       A      -79       A     -186       A
# 2      -95       A       49       A      -37       A      -70       A
# 3      312       A      230       P      330       A      337       A
# 4     -139       A     -367       A     -188       A     -407       A
#
# [5 rows x 78 columns]

# %%
columns = ["Gene_Description"]
columns.extend(RANGE_ALL)
columns.extend(RANGE_AML)

columns_data = []
columns_data.extend(RANGE_ALL)
columns_data.extend(RANGE_AML)

df = df[columns]
df.head()
# Out:
#                       Gene_Description  data_1  data_2  data_3  data_4  \
# 0  AFFX-BioB-5_at (endogenous control)    -214    -139     -76    -135
# 1  AFFX-BioB-M_at (endogenous control)    -153     -73     -49    -114
# 2  AFFX-BioB-3_at (endogenous control)     -58      -1    -307     265
# 3  AFFX-BioC-5_at (endogenous control)      88     283     309      12
# 4  AFFX-BioC-3_at (endogenous control)    -295    -264    -376    -419
#
#    data_5  data_6  data_7  data_8  data_9   ...     data_29  data_30  data_31  \
# 0    -106    -138     -72    -413       5   ...          15     -318      -32
# 1    -125     -85    -144    -260    -127   ...        -114     -192      -49
# 2     -76     215     238       7     106   ...           2      -95       49
# 3     168      71      55      -2     268   ...         193      312      230
# 4    -230    -272    -399    -541    -210   ...         -51     -139     -367
#
#    data_32  data_33  data_34  data_35  data_36  data_37  data_38
# 0     -124     -135      -20        7     -213      -25      -72
# 1      -79     -186     -207     -100     -252      -20     -139
# 2      -37      -70      -50      -57      136      124       -1
# 3      330      337      101      132      318      325      392
# 4     -188     -407     -369     -377     -209     -396     -324
#
# [5 rows x 39 columns]

# %%
df_all = df[RANGE_ALL]
df_aml = df[RANGE_AML]
df_aml.head()
# Out:
#    data_28  data_29  data_30  data_31  data_32  data_33  data_34  data_35  \
# 0       -4       15     -318      -32     -124     -135      -20        7
# 1     -116     -114     -192      -49      -79     -186     -207     -100
# 2     -125        2      -95       49      -37      -70      -50      -57
# 3      241      193      312      230      330      337      101      132
# 4     -191      -51     -139     -367     -188     -407     -369     -377
#
#    data_36  data_37  data_38
# 0     -213      -25      -72
# 1     -252      -20     -139
# 2      136      124       -1
# 3      318      325      392
# 4     -209     -396     -324

# %%
# df_all = df_all.applymap(lambda x: np.log(x) / np.log(2))
# df_aml = df_aml.applymap(lambda x: np.log(x) / np.log(2))

mean_all = df_all.mean(axis=1)  # means for 7129 genes
mean_aml = df_aml.mean(axis=1)   
var_all = df_all.var(axis=1)  # variance for 7129 genes
var_aml = df_aml.var(axis=1)

num_all = len(RANGE_ALL)  # number of samples of each condition
num_aml = len(RANGE_AML)

Z = (mean_all - mean_aml) / np.sqrt(var_all/num_all + var_aml/num_aml)
# print("means ALL: {}\n {}".format(len(mean_all), mean_all))
# print("means AML: {}\n {}".format(len(mean_aml), mean_aml))

print("Z mean: {}".format(Z.mean()))
print("Z std: {}".format(Z.std()))

"""
Z mean: 0.14004765578280895
Z std: 1.6058829875390022
Z means: 0.22008696871931546, 0.13073362322906437, 0.8692663767709357

Since the standard deviation is greater than 1, there appear to be multiple
genes for which the mean expression levels in the ALL and AML samples differ. 
Further, since the mean Z-score is positive, it appears that the dominant pattern
is for genes to be expressed at a higher level in the ALL compared to the AML samples.
"""

mean_z_mod = np.mean(np.abs(Z) > 2)
mean_z1 = np.mean(Z > 2)
mean_z2 = np.mean(Z < 2)

print("Z means: {}, {}, {}".format(mean_z_mod, mean_z1, mean_z2))
# Out:
# Z mean: 0.23653755413102437
# Z std: 1.7866583897611175
# Z means: 0.25866180389956517, 0.15948940945434142, 0.8405105905456586

# %%
"""
Genes with low expression level are harder to measure accurately, 
thus we expect that fewer of these genes will meet a given statistical
threshold for differential expression. Similarly, genes with low variance
are potentially less likely to be associated with biological differences.
We can assess these trends in our data. First, we will determine which
genes are in the lower and upper halves of all genes based on either 
mean expression or expression variation.
"""
SD = df[columns_data].std()
index_stdev_low = np.flatnonzero(SD < np.median(SD))
index_stdev_high = np.flatnonzero(SD > np.median(SD))

MEAN = df[columns_data].mean()
index_mean_low = np.flatnonzero(MEAN < np.median(MEAN))
index_mean_high = np.flatnonzero(MEAN > np.median(MEAN))

"""
Now we can look at the proportion of genes within each of these
strata that have Z-score magnitude greater than two.
"""
mean_low = np.mean(np.abs(Z[index_stdev_low]) > 2)
mean_high = np.mean(np.abs(Z[index_stdev_high]) > 2)

print("Check the mean of values with low Z magnitude: {}".format(mean_low))
print("Check the mean of values with high Z magnitude: {}".format(mean_high))
# Out:
# Check the mean of values with low Z magnitude: 0.2631578947368421
# Check the mean of values with high Z magnitude: 0.10526315789473684

# %%
## The Z-score threshold under a Bonferroni correction
zst = -norm.ppf(0.025/Z.shape[0])
indexes = np.flatnonzero(np.abs(Z) > zst)

print("Z-score threshold under a Bonferroni correction: {}".format(zst))
print("Found {} genes with Z > {}\n".format(len(indexes), zst))

with open(OUT_FILE, "w") as fout:
    for i in indexes:
        # print("Found gene: {} - {}".format(i, df["Gene Description"][i]))
        print("{} - {}".format(i, df["Gene_Description"][i]))
        fout.write("{},{}\n".format(Z[i], df["Gene_Description"][i]))
# Out:
# Z-score threshold under a Bonferroni correction: 4.4932751673227616
# Found 111 genes with Z > 4.4932751673227616
#
# 148 - Clone 22 mRNA, alternative splice variant alpha-1
# 228 - KIAA0102 gene
# 378 - AARS Alanyl-tRNA synthetase
# 435 - KIAA0097 gene
# 437 - T-COMPLEX PROTEIN 1, EPSILON SUBUNIT
# 460 - Liver mRNA for interferon-gamma inducing factor(IGIF)
# 531 - HMG1 High-mobility group (nonhistone chromosomal) protein 1
# 537 - KIAA0159 gene
# 653 - Non-lens beta gamma-crystallin like protein (AIM1) mRNA, partial cds
# 667 - KIAA0212 gene
# 696 - KIAA0235 gene, partial cds
# 803 - Macmarcks
# 877 - Heat Shock Protein, 70 Kda (Gb:Y00371)
# 1077 - ADPRT ADP-ribosyltransferase (NAD+; poly (ADP-ribose) polymerase)
# 1080 - UBIQUITIN-LIKE PROTEIN GDX
# 1143 - SPTAN1 Spectrin, alpha, non-erythrocytic 1 (alpha-fodrin)
# 1206 - Protein tyrosine kinase related mRNA sequence
# 1240 - IEF SSP 9502 mRNA
# 1244 - GBE1 Glucan (1,4-alpha-), branching enzyme 1 (glycogen branching enzyme, Andersen disease, glycogen storage disease type IV)
# 1248 - INDUCED MYELOID LEUKEMIA CELL DIFFERENTIATION PROTEIN MCL1
# 1305 - CRYZ Crystallin zeta (quinone reductase)
# 1620 - Motor protein
# 1629 - Inducible protein mRNA
# 1673 - FTL Ferritin, light polypeptide
# 1684 - Terminal transferase mRNA
# 1703 - ADA Adenosine deaminase
# 1744 - LYN V-yes-1 Yamaguchi sarcoma viral related oncogene homolog
# 1806 - Neuromedin B mRNA
# 1826 - TP53 Tumor protein p53 (Li-Fraumeni syndrome)
# 1833 - CD33 CD33 antigen (differentiation antigen)
# 1897 - LIPC Lipase, hepatic
# 1903 - CARCINOEMBRYONIC ANTIGEN PRECURSOR
# 1908 - IL7R Interleukin 7 receptor
# 1927 - Oncoprotein 18 (Op18) gene
# 2000 - CSF1 Colony-stimulating factor 1 (M-CSF)
# 2019 - FAH Fumarylacetoacetate
# 2049 - ZNF42 Zinc finger protein 42 (myeloid-specific retinoic acid-responsive)
# 2083 - DCK Deoxycytidine kinase
# 2110 - ATP6C Vacuolar H+ ATPase proton channel subunit
# 2130 - RPA1 Replication protein A1 (70kD)
# 2232 - NUCLEOLYSIN TIA-1
# 2241 - PEPTIDYL-PROLYL CIS-TRANS ISOMERASE, MITOCHONDRIAL PRECURSOR
# 2266 - CDC25A Cell division cycle 25A
# 2300 - ACTN2 Actinin alpha 2
# 2334 - IGB Immunoglobulin-associated beta (B29)
# 2347 - ACADM Acyl-Coenzyme A dehydrogenase, C-4 to C-12 straight chain
# 2353 - CCND3 Cyclin D3
# 2440 - HKR-T1
# 2496 - BLK Protein-tyrosine kinase blk
# 2625 - MSH2 DNA repair protein MSH2
# 2641 - MB-1 gene
# 2758 - Thrombospondin-p50 gene extracted from Human thrombospondin-1 gene, partial cds
# 2908 - SRP9 Signal recognition particle 9 kD protein
# 3055 - Cytoplasmic dynein light chain 1 (hdlc1) mRNA
# 3069 - Tax1-binding protein TXBP181 mRNA
# 3095 - Heterochromatin protein p25 mRNA
# 3136 - Stimulator of TAR RNA binding (SRB) mRNA
# 3311 - Protein kinase ATR mRNA
# 3319 - Leukotriene C4 synthase (LTC4S) gene
# 3390 - NADH:ubiquinone oxidoreductase subunit B13 (B13) mRNA
# 3506 - Putative enterocyte differentiation promoting factor mRNA, partial cds
# 3560 - JUN V-jun avian sarcoma virus 17 oncogene homolog
# 3659 - PLATELET-ACTIVATING FACTOR ACETYLHYDROLASE 45 KD SUBUNIT
# 3846 - GB DEF = Homeodomain protein HoxA9 mRNA
# 3898 - Serine kinase SRPK2 mRNA
# 4051 - Catalase (EC 1.11.1.6) 5'flank and exon 1 mapping to chromosome 11, band p13 (and joined CDS)
# 4057 - GJB1 Gap junction protein, beta 1, 32kD (connexin 32, Charcot-Marie-Tooth neuropathy, X-linked)
# 4152 - HISTONE H2A.X
# 4166 - ALDR1 Aldehyde reductase 1 (low Km aldose reductase)
# 4176 - IRF2 Interferon regulatory factor 2
# 4195 - PRG1 Proteoglycan 1, secretory granule
# 4210 - VIL2 Villin 2 (ezrin)
# 4229 - CTPS CTP synthetase
# 4288 - ADH4 gene for class II alcohol dehydrogenase (pi subunit), exon 1
# 4327 - PROTEASOME IOTA CHAIN
# 4367 - PROTEASOME ZETA CHAIN
# 4374 - DAGK1 Diacylglycerol kinase, alpha (80kD)
# 4388 - GTF2E2 General transcription factor TFIIE beta subunit, 34 kD
# 4437 - LMP2 gene extracted from H.sapiens genes TAP1, TAP2, LMP2, LMP7 and DOB
# 4447 - EWSR1 Ewing sarcoma breakpoint region 1
# 4534 - RETINOBLASTOMA BINDING PROTEIN P48
# 4568 - P130 mRNA for 130K protein
# 4581 - GLRX Glutaredoxin (thioltransferase)
# 4846 - Zyxin
# 4935 - GPX1 Glutathione peroxidase 1
# 4950 - Nucleoside-diphosphate kinase
# 4972 - RABAPTIN-5 protein
# 5038 - LEPR Leptin receptor
# 5071 - Cytokeratin 17
# 5074 - EEF1D Eukaryotic translation elongation factor 1 delta (guanine nucleotide exchange protein)
# 5190 - Adenosine triphosphatase, calcium
# 5253 - MCM3 Minichromosome maintenance deficient (S. cerevisiae) 3
# 5347 - CYP2C18 Cytochrome P450, subfamily IIC (mephenytoin 4-hydroxylase), polypeptide 18
# 5500 - TOP2B Topoisomerase (DNA) II beta (180kD)
# 5529 - Integrin cytoplasmic domain associated protein (Icap-1a) mRNA
# 5551 - PROBABLE G PROTEIN-COUPLED RECEPTOR LCR1 HOMOLOG
# 5592 - Transcriptional activator hSNF2b
# 5771 - C-myb gene extracted from Human (c-myb) gene, complete primary cds, and five complete alternatively spliced cds
# 6224 - CD19 gene
# 6280 - MYL1 Myosin light chain (alkali)
# 6282 - TCF3 Transcription factor 3 (E2A immunoglobulin enhancer binding factors E12/E47)
# 6470 - Thymopoietin beta mRNA
# 6514 - DHPS Deoxyhypusine synthase
# 6643 - Butyrophilin (BTF5) mRNA
# 6676 - HOX 2.2 gene extracted from Human Hox2.2 gene for a homeobox protein
# 6701 - LPAP gene
# 6800 - GB DEF = Retinoblastoma susceptibility protein (RB1) gene, with a 3 bp deletion in exon 22 (L11910 bases 161855-162161)
# 6854 - TCF3 Transcription factor 3 (E2A immunoglobulin enhancer binding factors E12/E47)
# 6894 - Uridine diphosphoglucose pyrophosphorylase mRNA
# 6973 - CD19 CD19 antigen
# 7118 - Transcriptional activator hSNF2b
